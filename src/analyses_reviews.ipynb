# %%
import pandas as pd

#For text processing
#Using this (https://bit.ly/2HvV2dx) as template
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer #, SnowballStemmer
from nltk.stem.porter import *
from nltk.tokenize import RegexpTokenizer, sent_tokenize, word_tokenize
tokenizer = RegexpTokenizer(r'\w+')
import numpy as np
np.random.seed(2018)
import nltk

# %%
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\chtra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chtra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# import pandas as pd

# df=pd.read_pickle('dftst.pkl')
df=pd.read_pickle('../data/hiking_attributes_ontario1.pkl')
print (len(df))
# df['review'][0]
df.head(50)

df_work=df.copy()
df_work.head(-10)
# Out:
# 437
#     difficulty distance elevation  \
# 0         EASY  15.9 km     149 m
# 1         EASY     5 km      14 m
# 2         EASY  15.6 km     166 m
# 3     MODERATE   3.4 km      23 m
# 4     MODERATE   4.7 km      64 m
# 5     MODERATE   2.3 km     100 m
# 6     MODERATE   7.2 km     128 m
# 7     MODERATE  15.3 km     427 m
# 8     MODERATE   2.9 km      71 m
# 9     MODERATE     8 km     222 m
# 10    MODERATE   9.5 km     197 m
# 11    MODERATE   7.2 km     230 m
# 12        EASY     9 km     301 m
# 13        HARD   9.8 km     460 m
# 14        EASY   5.3 km      81 m
# 15    MODERATE   2.3 km      93 m
# 16        EASY  10.3 km     370 m
# 17    MODERATE     4 km     156 m
# 18    MODERATE  14.5 km     174 m
# 19    MODERATE   3.7 km     106 m
# 20    MODERATE   4.8 km      93 m
# 21    MODERATE  12.2 km     408 m
# 22    MODERATE   3.2 km      57 m
# 23        EASY   5.1 km      84 m
# 24    MODERATE   1.9 km      71 m
# 25        EASY   4.7 km      12 m
# 26    MODERATE   5.8 km      66 m
# 27        EASY   4.5 km      72 m
# 28        EASY   6.1 km      93 m
# 29    MODERATE   7.6 km     243 m
# ..         ...      ...       ...
# 397   MODERATE   6.6 km      87 m
# 398   MODERATE   2.4 km      38 m
# 399       EASY   2.9 km      91 m
# 400       EASY   3.1 km      65 m
# 401       EASY   2.3 km       3 m
# 402       EASY   8.2 km     106 m
# 403       EASY   2.9 km      48 m
# 404       EASY   7.4 km     109 m
# 405   MODERATE     6 km     108 m
# 406   MODERATE  18.2 km     602 m
# 407       EASY  43.5 km     228 m
# 408       EASY   4.5 km     102 m
# 409   MODERATE  11.4 km     176 m
# 410       EASY   0.8 km       1 m
# 411       EASY   3.7 km      13 m
# 412       EASY   6.1 km       9 m
# 413       EASY   5.5 km      85 m
# 414   MODERATE  16.1 km     338 m
# 415   MODERATE   3.2 km      20 m
# 416   MODERATE   4.7 km     134 m
# 417       EASY   4.8 km     135 m
# 418   MODERATE   5.3 km     184 m
# 419   MODERATE  13.5 km     180 m
# 420       EASY    15 km      61 m
# 421   MODERATE   7.2 km     234 m
# 422       HARD     5 km     154 m
# 423       EASY   8.7 km     175 m
# 424   MODERATE  33.2 km     266 m
# 425       EASY   2.7 km      73 m
# 426   MODERATE   2.1 km      40 m
#
#                                                   name nreviews  \
# 0                                 Highland Creek Trail       33
# 1                         Unionville Valleylands Trail       29
# 2                    Greenwood Conservation Area Trail       31
# 3                                       Woodland Trail       22
# 4                                   Hilton Falls Trail      238
# 5                                   Niagara Glen Trail      135
# 6    Nassagaweya and Bruce Trail Loop from Rattlesn...      170
# 7                    Lion's Head Loop Via Bruce Trail       117
# 8        Dundas Peak via Bruce Trail and BT Side Trail       82
# 9    Forks of the Credit and Cataract Falls via Bru...      124
# 10                                 Dundas Valley Trail       94
# 11                                     The Crack Trail      120
# 12   McCarston's Lake Trail via Carriage and Spillw...      133
# 13                             Centennial Ridges Trail       85
# 14                                     Mount Nemo Loop       90
# 15                             Singhampton Caves Trail       98
# 16                    Waterdown Trail to Smokey Hollow       77
# 17         Thornton Bales Conservation Area Loop Trail      103
# 18                                 Seaton Hiking Trail      103
# 19   Tiffany Falls, Sherman Falls and Lower Little ...       60
# 20                      Bruce Trail - Burnt Point Loop       67
# 21                              Durham Regional Forest       65
# 22                              Black Creek Side Trail       59
# 23                                          Mast Trail       89
# 24                            Algonquin Lookout Trail        69
# 25                            Scarborough Bluffs Trail       69
# 26                  Heber Down Conservation Area Trail       68
# 27                   River and Ruin on the Bruce Trail       65
# 28                        Moore Park Ravine Trail Loop       64
# 29                               Track and Tower Trail       70
# ..                                                 ...      ...
# 397  Niagara Recreation Trail: Niagara Glen to the ...        6
# 398                        Rock Glen Conservation Loop        8
# 399                                   Kivi Park Trails       12
# 400              Laurel Creek Conservation Area Trail        13
# 401                        Ojibway Nature Centre Trail       13
# 402                Morrison Dam Conservation Area Loop        7
# 403                        Hilton Falls Reservoir Loop        7
# 404                  Marlborough Forest - Rideau Trail        4
# 405                    Ganaraska Trail to Shelton Lake       11
# 406                             Hockley Eastern Trails        5
# 407                                         K&P Trail        18
# 408                         Bruce Trail -Sydenham Loop       14
# 409                       Bronte Creek Trillium Trail         7
# 410                              Sifton Bog Dock Trail       20
# 411                                  Culham Trail Loop       16
# 412                     Port Weller - Waterfront Trail       11
# 413               Rideau Trail through Monaghan Forest       14
# 414     Bruce Trail: High Dump Camp Crane Lake Section        4
# 415                             Leslie Greenbelt Trail        9
# 416             Wasaga Section Ganaraska Hiking Trail         9
# 417                                  Loop D'Loop Trail       18
# 418  North Duchesnay Summit Trail to South Duchesna...        6
# 419                         PWT and Outback Loop Trail        9
# 420                                 Chinguacousy Trail        8
# 421                                   White Trail Loop       12
# 422                        Westcast Loop Under Hwy 403       15
# 423                               Monument Hill Trail         9
# 424                         Hilton Falls Extended Loop        9
# 425                     Proctor Park Conservation Area       12
# 426               Kakabeka Falls Beaver Meadows Trail         7
#
#                                                 review  route_type stars  \
# 0    Parts of this trail are very interesting but i...        Loop   4.4
# 1    Beautiful places to take some photosAs an aver...        Loop   3.9
# 2    The trail North of fifth concession is fantast...        Loop   4.1
# 3    As a trail was decent to run. It was not marke...        Loop   3.9
# 4    What a gem! I was so pleasantly  surprised by ...        Loop   4.3
# 5    Beautiful area with several trails.  Loved exp...        Loop   4.7
# 6    Great views! We went in January so there weren...        Loop   4.2
# 7    Amazing trail with stunning lookouts. Hiked it...        Loop   4.8
# 8    Love this trail. Great for all ages, just be c...        Loop   4.1
# 9    Hiking this trail for 25 years. Loveliest in t...        Loop   4.4
# 10   winter wonderlandGreat view in fallExcellent t...        Loop   4.5
# 11   Did this hike mid December, about of Foot of s...  Out & Back   4.8
# 12   Was a nice hike. Roughly 3 hours. A lot of ice...        Loop   4.3
# 13   This is the hike that I compare all others to....        Loop   4.9
# 14   Moderate hike if you do the red loop and see t...        Loop   4.4
# 15   The Singhampton Caves Trail is part of the Not...        Loop   4.8
# 16   everything I want in a trail - water fall, lar...  Out & Back   4.5
# 17   This seems like a great trail and will enjoy a...        Loop   4.3
# 18   Decent walk.. Wouldn’t say I thought it was fa...  Out & Back   3.9
# 19   Love it in autumn. Great fall colours and beau...  Out & Back   4.2
# 20   Good leisure hikeGreat alternative to the Grot...        Loop   4.5
# 21   nice trails & confusing to maneuver for rookie...        Loop   4.4
# 22   Such a great walk! Got stuck trying to do the ...        Loop   4.3
# 23   Nice forested walk with litigation side trails...        Loop   4.2
# 24   hiked this trail October 15 2018.  it was a go...        Loop   4.6
# 25   Yes very good trail, I like to dump in the bus...  Out & Back   3.9
# 26   great trailGreat spot for a quick hike.  Was g...  Out & Back   4.2
# 27   Was nice. A little muddy. We followed the trai...        Loop   4.4
# 28   Beautiful trail in the heart of the city.  Fam...        Loop   4.3
# 29   I arrived around 10am on a cold but sunny Satu...        Loop   4.5
# ..                                                 ...         ...   ...
# 397                                                     Out & Back   4.2
# 398  Nice trail and not to difficult for kids ages ...        Loop   4.3
# 399  Amazing gift to the community. Well marked and...        Loop   4.2
# 400  Walking trails, not hiking. Nice scenery.Come ...        Loop   4.2
# 401  Quiet, nature filled quick wander.It’s a bit m...        Loop   3.7
# 402  fantastic trail, beautiful scenery! its defini...        Loop   5.0
# 403                      Always a nice place to visit!        Loop   4.3
# 404  One of our favourite places to walk with the d...        Loop   5.0
# 405  Great trail. Challenging with lots of up and d...  Out & Back   4.3
# 406  Took 4.5 to do this whole trail from Hockley R...        Loop   3.6
# 407  I ride the KP all the time my family’s farm is...  Out & Back   3.7
# 408  Easy trail. Nice views especially in the winte...        Loop   4.0
# 409  This route should better be described as ravin...        Loop   4.0
# 410  Short and SweetA beautiful little walk, but ve...  Out & Back   3.6
# 411  It was done in a group. So couldn’t leave. It ...        Loop   3.2
# 412  Good walking path, can be really interesting i...        Loop   4.1
# 413  A fun hike though the Forest.  It was cool in ...        Loop   3.1
# 414  Awesome day hike! We also camped over night at...  Out & Back   5.0
# 415  its not a bad short hike if you are in the are...  Out & Back   3.6
# 416                                                     Out & Back   3.8
# 417  beautiful walk. slightly icy in spots as we we...        Loop   4.2
# 418  Beautiful, but why is it brown and foamy?The "...        Loop   4.5
# 419  The recorded trail goes off trail at a few spo...        Loop   4.0
# 420  ExcelenteChingcousy park was very nice.  Pleas...  Out & Back   4.0
# 421  Trail itself is actually about 2km but during ...        Loop   4.8
# 422  Good fun to hike in an afternoon, trail is not...        Loop   3.7
# 423  Nice trail to get out for a few hoursNot reall...        Loop   4.2
# 424  My go to woodlot. So much to see and do on the...        Loop   4.6
# 425  Absolutely loved this little trail. An easy wa...        Loop   4.3
# 426  There was lots to explore. There were a few ch...        Loop   4.1
#
#                                       trail_attributes
# 0    [dogs on leash, hiking, mountain biking, road ...
# 1    [dogs on leash, wheelchair friendly, kid frien...
# 2    [dogs on leash, kid friendly, birding, hiking,...
# 3    [dogs on leash, kid friendly, hiking, trail ru...
# 4    [dogs on leash, birding, cross country skiing,...
# 5    [dogs on leash, kid friendly, hiking, nature t...
# 6    [dogs on leash, kid friendly, hiking, nature t...
# 7    [dogs on leash, birding, hiking, nature trips,...
# 8    [dogs on leash, birding, hiking, road biking, ...
# 9    [dogs on leash, birding, hiking, nature trips,...
# 10   [dogs on leash, kid friendly, birding, hiking,...
# 11   [dog friendly, birding, fishing, hiking, natur...
# 12   [dogs on leash, kid friendly, birding, hiking,...
# 13   [dogs on leash, birding, camping, hiking, natu...
# 14   [dogs on leash, kid friendly, hiking, trail ru...
# 15   [dogs on leash, kid friendly, birding, hiking,...
# 16   [dogs on leash, kid friendly, birding, hiking,...
# 17   [dogs on leash, birding, hiking, trail running...
# 18   [dogs on leash, birding, cross country skiing,...
# 19   [dogs on leash, birding, hiking, nature trips,...
# 20   [dogs on leash, birding, hiking, nature trips,...
# 21   [dogs on leash, birding, hiking, mountain biki...
# 22   [dog friendly, hiking, nature trips, trail run...
# 23   [dogs on leash, birding, hiking, nature trips,...
# 24   [dogs on leash, hiking, trail running, walking...
# 25   [dogs on leash, kid friendly, hiking, walking,...
# 26   [dog friendly, hiking, mountain biking, trail ...
# 27   [dogs on leash, birding, hiking, nature trips,...
# 28   [dogs on leash, kid friendly, hiking, mountain...
# 29   [dogs on leash, hiking, trail running, walking...
# ..                                                 ...
# 397  [dogs on leash, kid friendly, hiking, trail ru...
# 398  [dogs on leash, hiking, forest, waterfall, his...
# 399  [dogs on leash, kid friendly, cross country sk...
# 400  [dogs on leash, kid friendly, hiking, paddle s...
# 401  [dogs on leash, kid friendly, hiking, mountain...
# 402  [dogs on leash, kid friendly, cross country sk...
# 403  [dogs on leash, kid friendly, birding, hiking,...
# 404  [dogs on leash, kid friendly, hiking, snowshoe...
# 405  [dog friendly, kid friendly, camping, hiking, ...
# 406  [dog friendly, birding, hiking, nature trips, ...
# 407  [birding, hiking, mountain biking, nature trip...
# 408  [kid friendly, birding, hiking, nature trips, ...
# 409  [dogs on leash, camping, hiking, trail running...
# 410  [dogs on leash, kid friendly, birding, hiking,...
# 411  [dogs on leash, kid friendly, hiking, trail ru...
# 412  [dogs on leash, wheelchair friendly, kid frien...
# 413  [dogs on leash, kid friendly, birding, cross c...
# 414  [dogs on leash, backpacking, birding, camping,...
# 415  [dog friendly, kid friendly, birding, hiking, ...
# 416  [dogs on leash, kid friendly, birding, hiking,...
# 417  [dogs on leash, kid friendly, birding, hiking,...
# 418  [hiking, mountain biking, snowshoeing, trail r...
# 419  [dogs on leash, birding, hiking, mountain biki...
# 420  [dogs on leash, wheelchair friendly, kid frien...
# 421  [dogs on leash, hiking, snowshoeing, walking, ...
# 422  [dogs on leash, birding, hiking, mountain biki...
# 423  [dogs on leash, kid friendly, birding, hiking,...
# 424  [dogs on leash, birding, hiking, mountain biki...
# 425  [dogs on leash, kid friendly, hiking, mountain...
# 426  [dogs on leash, birding, hiking, mountain biki...
#
# [427 rows x 9 columns]

# %%
# def lemmatize_stemming(text):
#     return PorterStemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    words=[word for sentence in sent_tokenize(text) for word in word_tokenize(sentence)]
    words=[word for word in words if len(word)>3]
    words=[word for word in words if word not in gensim.parsing.preprocessing.STOPWORDS]
    words=[WordNetLemmatizer().lemmatize(word) for word in words]
    #Lemmatize
#     words=[WordNetLemmatizer.lemmatize(word) for word in words]
    return words

# %%
import string
import re
reviews=df_work.review
#tokenize text
# reviews.apply(lambda x: x.lower())
reviews=reviews.str.lower()
reviews=reviews.str.replace('\"', '')
reviews=reviews.str.replace("\'", '')
reviews=reviews.str.replace('\"', '')
reviews=reviews.str.replace('\!', '')
reviews=reviews.str.replace('\/', ' ')
reviews=reviews.str.replace(',', '')
reviews=reviews.str.replace('(', '')
reviews=reviews.str.replace(')', '')
reviews=reviews.str.replace('.', '')
reviews=reviews.str.replace('\d+', '')
reviews=reviews.replace(to_replace={'hik', 'walk','run','trail', 'interesting',\
                                    'good','great','lot','recommend','area','park',\
                                    'love','like','way','easy'}, value='', regex=True)

processed_text=[preprocess(text) for text in reviews]
# lemmatized_text=[WordNetLemmatizer.lemmatize(text) for text in reviews]
# WordNetLemmatizer.lemmatize('are')

# reviews.head(50)
print (processed_text[0], reviews[0])
# print ()
# Out:
# ['part', 'paved', 'time', 'road', 'closed', 'couple', 'place', 'forcing', 'road', 'probably', 'route', 'bike', 'bikinga', 'paved', 'take', 'wooded', 'spent', 'hour', 'came', 'couple', 'deer', 'beaver', 'bunny', 'tiniest', 'squirrel', 'seen', 'chipmunk', 'bench', 'scenic', 'break', 'pit', 'bbqs', 'splash', 'jungle', 'near', 'main', 'lived', 'close', 'year', 'idea', 'place', 'pointed', 'outstarted', 'west', 'entrance', 'east', 'point', 'quick', 'small', 'forest', 'lakeshore', 'picnic', 'soft', 'mulcha', 'beautiful', 'traverse', 'beautiful', 'wooded', 'paved', 'path', 'wouldnt', 'know', 'youre', 'city', 'suddenly', 'lake', 'appears', 'view', 'beautiful', 'vista', 'ride', 'lakeshore', 'round', 'trip', 'starting', 'highland', 'creek', 'rode', 'east', 'itdid', 'quick', 'yesterday', 'amazing', 'wilderness', 'city', 'sung', 'skirted', 'tennis', 'court', 'built', 'campus', 'panam', 'game', 'amazing', 'growth', 'forest', 'wetland', 'highland', 'creek', 'choice', 'leaving', 'city', 'right', 'kingston', 'road', 'miss'] parts of this  are very  but it is almost all paved and there is too much time ing on roads the  was closed in a couple places forcing us back onto roads probably a  route to bike  as fun for bikinga paved  that takes you through  wooded s spent only an hour ing and came across a couple deer a beaver many bunnies and the tiniest squirrel i have ever seen no not a chipmunk several benches along the  to take scenic breaks there are fire pits and bbqs as well as a splash pad and jungle gym near the main ing  i have lived very close to this  for  years and had no idea this place was here until the app pointed it outstarted at west entrance of east point  for an  quick  in small forest and along the lakeshore can picnic soft mulcha beautiful   that traverses beautiful wooded  on  paved paths where you wouldnt even know youre in the city then suddenly the lake appears in front of view - a beautiful vista a ride along the lakeshore is ly as well we did about  km round trip starting from the highland creek ing  and rode east go for itdid about   of this  for a quick  yesterday  an amazing wilderness in the city  on the  back we sung by and skirted the tennis courts they have built on the u of t campus for the panam games  amazing thick of growth forest and wetlands on one side highland creek on the other - its a  choice for a  without leaving the city  ing is right along old kingston road - you cant miss it

# %%
#Add processed text as a new column
df_work['processed_text']= pd.Series(processed_text)
df_work.head()
#[' '.join(filter(None,filter(lambda word: word not in stop, line))) for line in data['text_data'].str.lower().str.split(' ')]
# Out:
#   difficulty distance elevation                               name nreviews  \
# 0       EASY  15.9 km     149 m               Highland Creek Trail       33
# 1       EASY     5 km      14 m       Unionville Valleylands Trail       29
# 2       EASY  15.6 km     166 m  Greenwood Conservation Area Trail       31
# 3   MODERATE   3.4 km      23 m                     Woodland Trail       22
# 4   MODERATE   4.7 km      64 m                 Hilton Falls Trail      238
#
#                                               review route_type stars  \
# 0  Parts of this trail are very interesting but i...       Loop   4.4
# 1  Beautiful places to take some photosAs an aver...       Loop   3.9
# 2  The trail North of fifth concession is fantast...       Loop   4.1
# 3  As a trail was decent to run. It was not marke...       Loop   3.9
# 4  What a gem! I was so pleasantly  surprised by ...       Loop   4.3
#
#                                     trail_attributes  \
# 0  [dogs on leash, hiking, mountain biking, road ...
# 1  [dogs on leash, wheelchair friendly, kid frien...
# 2  [dogs on leash, kid friendly, birding, hiking,...
# 3  [dogs on leash, kid friendly, hiking, trail ru...
# 4  [dogs on leash, birding, cross country skiing,...
#
#                                       processed_text
# 0  [part, paved, time, road, closed, couple, plac...
# 1  [beautiful, place, photosas, average, bike, ri...
# 2  [north, fifth, concession, fantastic, place, c...
# 3  [decent, marked, desired, ended, adding, dista...
# 4  [pleasantly, surprised, arriving, entrance, ga...

# %%
# df_work.processed_text[0]

# %%
#Creating word countf for IDF
from sklearn.feature_extraction.text import CountVectorizer
import re
 
def get_stop_words(stop_file_path):
    """load stop words """
    
    with open(stop_file_path, 'r', encoding="utf-8") as f:
        stopwords = f.readlines()
        stop_set = set(m.strip() for m in stopwords)
        return frozenset(stop_set)
 
#load a set of stop words
stopwords=get_stop_words("../data/stop_words.txt")
 
#get the text column 
docs=df_work['processed_text'][0] #.tolist()
 
#create a vocabulary of words, 
#ignore words that appear in 85% of documents, 
#eliminate stop words
cv=CountVectorizer(max_df=0.85,stop_words=stopwords)
word_count_vector=cv.fit_transform(docs)
# Out:
# C:\Users\chtra\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['come', 'vis', 'viser', 'visest'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
list(cv.vocabulary_.keys())[:20]
# word_count_vector
# Out:
# ['part',
#  'paved',
#  'time',
#  'road',
#  'closed',
#  'couple',
#  'place',
#  'forcing',
#  'route',
#  'bike',
#  'bikinga',
#  'take',
#  'wooded',
#  'spent',
#  'hour',
#  'came',
#  'deer',
#  'beaver',
#  'bunny',
#  'tiniest']

# %%
from sklearn.feature_extraction.text import TfidfTransformer
 
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
from gensim import corpora
dictionary = corpora.Dictionary(df_work['processed_text'])
corpus = [dictionary.doc2bow(text) for text in df_work['processed_text']]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.020*"nice" + 0.011*"beautiful" + 0.009*"time" + 0.009*"river"')
# (1, '0.016*"view" + 0.013*"beautiful" + 0.012*"nice" + 0.008*"rock"')
# (2, '0.009*"fall" + 0.006*"nice" + 0.005*"marked" + 0.004*"road"')
# (3, '0.024*"view" + 0.016*"nice" + 0.014*"beautiful" + 0.012*"lake"')
# (4, '0.008*"section" + 0.006*"river" + 0.006*"road" + 0.005*"time"')

# %% [markdown]
# Topic modeling based on this: https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24

# %%
# processed_text
dictionary = gensim.corpora.Dictionary(processed_text)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
len(dictionary)
# Out:
# 0 amazing
# 1 appears
# 2 bbqs
# 3 beautiful
# 4 beaver
# 5 bench
# 6 bike
# 7 bikinga
# 8 break
# 9 built
# 10 bunny
# 7534

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=10000)
len(dictionary)
# Out:
# 463

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_text]
print (len(bow_corpus))
# bow_corpus[41]
# bow_corpus
# Out:
# 437

# %%
bow_doc_400 = bow_corpus[10]
# for i in range(len(bow_doc_400)):
#     print("Word {} (\"{}\") appears {} time.".format(bow_doc_400[i][0], 
#                                                dictionary[bow_doc_400[i][0]], 
# bow_doc_400[i][1]))

# %%
#Bag of words
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
#     pprint(doc)
    break

# %%
#Train lda model using gensim.models.LdaMulticore and save it to ‘lda_model’
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)
#Explore words in topic and relative weight
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.032*"lake" + 0.023*"place" + 0.019*"beach" + 0.016*"little" + 0.015*"dog" + 0.012*"definitely" + 0.011*"cliff" + 0.010*"long" + 0.010*"enjoy" + 0.009*"kid"
# Topic: 1
# Words: 0.015*"lake" + 0.014*"dog" + 0.014*"little" + 0.014*"marked" + 0.013*"forest" + 0.013*"hill" + 0.012*"place" + 0.012*"path" + 0.011*"time" + 0.011*"bridge"
# Topic: 2
# Words: 0.017*"hill" + 0.017*"forest" + 0.016*"loop" + 0.014*"road" + 0.014*"dog" + 0.014*"path" + 0.013*"time" + 0.013*"section" + 0.012*"river" + 0.012*"little"
# Topic: 3
# Words: 0.017*"time" + 0.017*"river" + 0.013*"road" + 0.012*"rock" + 0.011*"bike" + 0.011*"little" + 0.011*"fall" + 0.010*"lake" + 0.010*"path" + 0.009*"hour"
# Topic: 4
# Words: 0.019*"loop" + 0.013*"short" + 0.012*"little" + 0.011*"time" + 0.011*"forest" + 0.010*"tree" + 0.010*"fall" + 0.010*"place" + 0.010*"lake" + 0.010*"hour"
# Topic: 5
# Words: 0.015*"rock" + 0.015*"loop" + 0.014*"lake" + 0.014*"time" + 0.013*"challenging" + 0.013*"point" + 0.012*"marked" + 0.011*"beach" + 0.011*"pretty" + 0.011*"amazing"
# Topic: 6
# Words: 0.026*"lake" + 0.016*"time" + 0.015*"place" + 0.014*"moderate" + 0.013*"waterfall" + 0.013*"worth" + 0.012*"water" + 0.012*"rock" + 0.011*"spot" + 0.011*"definitely"
# Topic: 7
# Words: 0.029*"dog" + 0.020*"time" + 0.018*"place" + 0.016*"family" + 0.014*"section" + 0.014*"board" + 0.012*"hour" + 0.011*"path" + 0.011*"conservation" + 0.010*"come"
# Topic: 8
# Words: 0.022*"time" + 0.014*"lake" + 0.013*"water" + 0.012*"lookout" + 0.011*"marked" + 0.010*"forest" + 0.010*"creek" + 0.009*"place" + 0.009*"spot" + 0.009*"year"
# Topic: 9
# Words: 0.047*"fall" + 0.019*"little" + 0.016*"time" + 0.012*"definitely" + 0.012*"loop" + 0.011*"took" + 0.011*"waterfall" + 0.011*"challenging" + 0.010*"place" + 0.010*"bruce"

# %%
#LDA using TF-IDF
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.010*"fall" + 0.010*"lake" + 0.008*"river" + 0.008*"ride" + 0.008*"bruce" + 0.007*"short" + 0.007*"rock" + 0.007*"stair" + 0.006*"water" + 0.006*"waterfall"
# Topic: 1 Word: 0.009*"creek" + 0.009*"amazing" + 0.009*"direction" + 0.008*"river" + 0.008*"wildlife" + 0.007*"point" + 0.007*"marked" + 0.007*"beach" + 0.006*"lake" + 0.006*"house"
# Topic: 2 Word: 0.008*"wife" + 0.008*"rocky" + 0.008*"kid" + 0.008*"lake" + 0.007*"daughter" + 0.007*"deer" + 0.007*"ontario" + 0.007*"turned" + 0.007*"plenty" + 0.006*"pine"
# Topic: 3 Word: 0.011*"paved" + 0.010*"creek" + 0.007*"short" + 0.007*"forest" + 0.007*"fall" + 0.007*"muddy" + 0.007*"hill" + 0.007*"city" + 0.006*"road" + 0.006*"marking"
# Topic: 4 Word: 0.007*"fall" + 0.007*"river" + 0.007*"loop" + 0.007*"lake" + 0.007*"rock" + 0.006*"challenging" + 0.006*"hour" + 0.006*"path" + 0.006*"time" + 0.006*"marked"
# Topic: 5 Word: 0.008*"maintained" + 0.008*"bike" + 0.008*"wooded" + 0.008*"river" + 0.008*"perfect" + 0.008*"place" + 0.008*"lake" + 0.006*"dog" + 0.006*"scenic" + 0.006*"lead"
# Topic: 6 Word: 0.009*"lake" + 0.008*"busy" + 0.008*"watch" + 0.008*"went" + 0.007*"dog" + 0.007*"leash" + 0.007*"place" + 0.007*"visit" + 0.006*"city" + 0.006*"path"
# Topic: 7 Word: 0.009*"fall" + 0.008*"lake" + 0.008*"dog" + 0.008*"different" + 0.007*"variety" + 0.007*"little" + 0.007*"snow" + 0.007*"water" + 0.007*"today" + 0.007*"people"
# Topic: 8 Word: 0.013*"wood" + 0.011*"creek" + 0.010*"beginner" + 0.009*"option" + 0.007*"short" + 0.007*"leaf" + 0.007*"tree" + 0.007*"beaver" + 0.007*"dog" + 0.007*"muddy"
# Topic: 9 Word: 0.014*"cave" + 0.009*"town" + 0.008*"simple" + 0.008*"awesome" + 0.008*"river" + 0.008*"winter" + 0.008*"scenic" + 0.007*"loop" + 0.007*"rock" + 0.007*"short"

# %%
#Performance evaluation-LDA bag of words
n=10

print (processed_text[n])
for index, score in sorted(lda_model[bow_corpus[n]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# ['winter', 'wonderland', 'view', 'fallexcellent', 'marked', 'minute', 'dogsuch', 'beautiful', 'spot', 'choose', 'quick', 'spend', 'time', 'lost', 'forest', 'hour', 'favorite', 'feeling', 'chance', 'main', 'quick', 'stop', 'hermitage', 'ruin', 'griffith', 'house', 'seeing', 'absolutely', 'want', 'return', 'multiple', 'time', 'maybe', 'biking', 'gorgeous', 'fall', 'marked', 'throughlyid', 'sure', 'pretty', 'busy', 'worked', 'favour', 'license', 'fell', 'pocket', 'biker', 'encountered', 'incredibly', 'nice', 'confusing', 'path', 'intersection', 'marked', 'unmarked', 'map', 'arent', 'helping', 'incredibly', 'helpful', 'thankful', 'cheaper', 'depending', 'start', 'artaban', 'start', 'long', 'hill', 'view', 'wonderful', 'variety', 'depending', 'looking', 'family', 'amazing', 'dont', 'entrance', 'feethere', 'dundas', 'valley', 'long', 'short', 'want', 'kept', 'enjoyed', 'herethis', 'place', 'amazing', 'peaceful', 'beautiful', 'wildlife', 'variety', 'elevation', 'stream', 'possible', 'route', 'want', 'leaveamazing', 'place', 'beautiful', 'groomed', 'amazing', 'scenery', 'posted', 'horse', 'rider', 'bridge', 'recognize', 'enlargement', 'contact', 'glenbylsma', 'yahooca', 'thanks', 'photo', 'sectionjust', 'best', 'place', 'felt', 'amazing', 'seeing', 'green', 'definitely', 'againthis', 'amazing', 'elevation', 'change', 'waterfall', 'incredible', 'biodiversity', 'heavily', 'adding', 'sherman', 'fall', 'mccormack', 'easier', 'beautiful', 'additionsit', 'variation', 'elevation', 'beautiful', 'scenery', 'thing', 'suggest', 'putting', 'closer', 'beginning', 'variety', 'hill', 'keep', 'beautiful', 'scenery', 'main', 'sign', 'marker', 'appno', 'guessing', 'amthis', 'staple', 'main', 'loop', 'year', 'gentle', 'terrain', 'nice', 'rocky', 'stream', 'tall', 'tree', 'friendly', 'horse', 'rider', 'busy', 'mountain', 'bike', 'rider', 'weekend', 'nice', 'highlight', 'center', 'wild', 'life', 'fact', 'amazing', 'style', 'steam', 'train', 'overall', 'nice', 'main', 'loop', 'gravel', 'path', 'forest', 'meadow', 'environment', 'fairly', 'steep', 'climb', 'overall', 'manageable', 'scenery', 'option', 'level', 'beautiful', 'taken', 'care', 'mentioned', 'waterfall', 'specifically', 'came', 'young', 'kidsi', 'went', 'said', 'waterfall', 'followed', 'pretty', 'diligently', 'waterfall', 'get', 'immaculately', 'groomed', 'beautiful', 'forestry', 'mile', 'head', 'location', 'closer', 'waterfall', 'different', 'section']
#
# Score: 0.6775578856468201
# Topic: 0.017*"hill" + 0.017*"forest" + 0.016*"loop" + 0.014*"road" + 0.014*"dog" + 0.014*"path" + 0.013*"time" + 0.013*"section" + 0.012*"river" + 0.012*"little"
#
# Score: 0.23173841834068298
# Topic: 0.047*"fall" + 0.019*"little" + 0.016*"time" + 0.012*"definitely" + 0.012*"loop" + 0.011*"took" + 0.011*"waterfall" + 0.011*"challenging" + 0.010*"place" + 0.010*"bruce"
#
# Score: 0.0772574245929718
# Topic: 0.017*"time" + 0.017*"river" + 0.013*"road" + 0.012*"rock" + 0.011*"bike" + 0.011*"little" + 0.011*"fall" + 0.010*"lake" + 0.010*"path" + 0.009*"hour"

# %%
#Performance evaluation-LDA TF-IDF
trailnum=40
# print (processed_text[trailnum])
print (df_work.iloc[trailnum])
for index, score in sorted(lda_model_tfidf[bow_corpus[40]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# difficulty                                                       EASY
# distance                                                       7.9 km
# elevation                                                       172 m
# name                                      Vicki Barron Lakeside Trail
# nreviews                                                           49
# review              Great trail easy not moderate. Worth coming ye...
# route_type                                                 Out & Back
# stars                                                             4.4
# trail_attributes    [dogs on leash, wheelchair friendly, kid frien...
# processed_text      [moderate, worth, coming, year, round, beautif...
# Name: 40, dtype: object
#
# Score: 0.9674081206321716
# Topic: 0.007*"fall" + 0.007*"river" + 0.007*"loop" + 0.007*"lake" + 0.007*"rock" + 0.006*"challenging" + 0.006*"hour" + 0.006*"path" + 0.006*"time" + 0.006*"marked"
#
# Score: 0.024896953254938126
# Topic: 0.009*"fall" + 0.008*"lake" + 0.008*"dog" + 0.008*"different" + 0.007*"variety" + 0.007*"little" + 0.007*"snow" + 0.007*"water" + 0.007*"today" + 0.007*"people"

# %%
# # run word2vec model and then save it
# texts_stemmed = filter(None, [next_text.strip(' ').split(' ') for next_text in df_work['processed_text'][0]])
# w2vmodel_stemmed = gensim.models.Word2Vec(texts_stemmed, size=100, window=5, min_count=5, workers=4)
# w2vmodel_stemmed.save(savefolder+'w2v_stemmed_model')

# %% [markdown]
# ###  Sentiment analysis of reviews

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
mystr = 'it\'s a nice trail with some dirty puddles, but fine overall'
mystr = 'amazing trail with decent views'
mystr = 'wonderful trail'
mystr = df_work['review'][98]
# print (mystr)
sentiment_analyzer_scores(mystr)
# Out:
# started at brickworks and headed up to mount pleasant where path is paved and flat (i.e. many families and strollers). coming back down through balfour park is not stroller friendly at all for about 1km, then there is a split, where a paved trail can be rejoined.This is a perfect getaway close to downtown, both for walking and jogging, and with a bit of detour also for biking. {'neg': 0.037, 'neu': 0.864, 'pos': 0.099, 'compound': 0.6566}

# %% [markdown]
# ### Text summarization using gensim

# %%
from gensim.summarization.summarizer import summarize

# %%
text=df.review[355]
print (text)
summarize(text, word_count=50, split=False)
# Out:
# great kid-friendly family trailWent for a fall hike today and it was soo beautiful!! Love water falls!  And the big rocks!Awesome mountain biking track in great shape! There were 2 clear lines to follow - I had a blast!
# 'great kid-friendly family trailWent for a fall hike today and it was soo beautiful!!\nLove water falls!\nAnd the big rocks!Awesome mountain biking track in great shape!\nThere were 2 clear lines to follow - I had a blast!'

# %%
# text=df.review[11]
# from gensim.summarization import keywords
print (keywords(str(text)))
# Out:
# trail
# trails
# nice
# closed
# unionville
# beautiful
# view
# viewing
# evening
# bike
# gold
# conservation
# dam
# went
# construction
# outingin
# flat
# creek
# bridges
# bridge

# %% [markdown]
# ###  Text summarization using NLTK

# %% [markdown]
# Based on https://medium.com/jatana/unsupervised-text-summarization-using-sentence-embeddings-adb15ce83db1

# %%
text=df.review[1]
from nltk.tokenize import sent_tokenize


sentences=sent_tokenize(text)
# sentences

# %%
tnum=100
proctxt = [' '.join(txt for txt in processed_text[tnum])]
print(proctxt[0])

from gensim.summarization import keywords
(keywords(proctxt[0])).replace('\n', ' ')
# Out:
# wonderful beamer conservation view escarpment amazing look nice view lake ontario nice snow part bruce came terrain flat uneven river provide scenerya relatively creek stair leading catch look point stair waterfall cool edge dangerous solid footing definitely againlight small kid plenty gorgeous view maintained fitting wide range experience levelsluxurious mysteriousnice sorta loop path lost viewsthe loop nice relaxing wide gravel enjoy look point rest wide natural obstacle sloped stair challenge perfect us incredible view looking grimsby lake escarpment terrain give natural landscape give trial character fall little tricky vegetation plus give unspoilt qualityed late january amazing winter icers tricky patch worry beautiful frozen river feature water flow moving rapidly creamy french vanilla snow frozen sheet beautiful steep rocky lookout short worth winterpleasant view lake creek mini cavern beamers fall amazing rippled gently sloped waterfall ideal beginner intermediate erals quick familyreally sure wear shoe week view opinion different skill levelsnice climb start plenty view toilet block availablethis viewsthis probably best beautiful scenery tree phenomenal water fall beautiful havent youre missing view nice footing optionsconnects bruce
# 'view escarpment amazing look nice looking wide fall beautiful frozen creek stair tricky lake beamer beamers footing water loop river waterfall plenty sloped natural terrain qualityed snow'
